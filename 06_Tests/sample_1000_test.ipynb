# %%
import pandas as pd
opioid_test = pd.read_csv(
    "sample_data_1000_opoidshipment(prescription_b2b).csv"
    )
print(opioid_test)
# Out:
#            Unnamed: 0        Unnamed: 1            Unnamed: 2  \
# 0     REPORTER_DEA_NO  REPORTER_BUS_ACT         REPORTER_NAME
# 1           RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 2           RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 3           RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 4           RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# ...               ...               ...                   ...
# 996         RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 997         RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 998         RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 999         RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
# 1000        RM0220688       DISTRIBUTOR  MCKESSON CORPORATION
#
#                  Unnamed: 3             Unnamed: 4         Unnamed: 5  \
# 0     REPORTER_ADDL_CO_INFO      REPORTER_ADDRESS1  REPORTER_ADDRESS2
# 1                       NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
# ...
